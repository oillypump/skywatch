# %%
from pyiceberg.catalog import load_catalog

catalog = load_catalog(
    "default",
    **{
        "type": "hive",
        "uri": "thrift://hive-metastore:9083",
        "s3.endpoint": "http://minio:9000",   
        "s3.access-key-id": "minioadmin",
        "s3.secret-access-key": "minioadmin",
        "s3.use-ssl": "false",
    }
)

# %%
catalog.list_namespaces()
# Out:
# [('default',)]

# %%
import pandas as pd
import pyarrow.parquet as pq

# %%
arrow_table = pq.read_table("../data/yellow_tripdata_2023-01.parquet")
table_id = "test_schema.yellow_taxi_2"

try:
    table = catalog.create_table(
        table_id,
        schema=arrow_table.schema,
        location=f"s3a://warehouse/{table_id}"
    )
except Exception:
    table = catalog.load_table(table_id)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[11], line 5
#       4 try:
# ----> 5     table = catalog.create_table(
#       6         table_id,
#       7         schema=arrow_table.schema,
#       8         location=f"s3a://warehouse/{table_id}"
#       9     )
#      10 except Exception:
#
# File ~/werk/odp_lab/.venv/lib/python3.12/site-packages/pyiceberg/catalog/hive.py:433, in HiveCatalog.create_table(self, identifier, schema, location, partition_spec, sort_order, properties)
#     431 database_name, table_name = self.identifier_to_database_and_table(identifier)
# --> 433 self._write_metadata(staged_table.metadata, staged_table.io, staged_table.metadata_location)
#     434 tbl = self._convert_iceberg_into_hive(staged_table)
#
# File ~/werk/odp_lab/.venv/lib/python3.12/site-packages/pyiceberg/catalog/__init__.py:1005, in MetastoreCatalog._write_metadata(metadata, io, metadata_path)
#    1003 @staticmethod
#    1004 def _write_metadata(metadata: TableMetadata, io: FileIO, metadata_path: str) -> None:
# -> 1005     ToOutputFile.table_metadata(metadata, io.new_output(metadata_path))
#
# File ~/werk/odp_lab/.venv/lib/python3.12/site-packages/pyiceberg/serializers.py:130, in ToOutputFile.table_metadata(metadata, output_file, overwrite)
#     124 """Write a TableMetadata instance to an output file.
#     125
#     126 Args:
#     127     output_file (OutputFile): A custom implementation of the iceberg.io.file.OutputFile abstract base class.
#     128     overwrite (bool): Where to overwrite the file if it already exists. Defaults to `False`.
#     129 """
# --> 130 with output_file.create(overwrite=overwrite) as output_stream:
#     131     # We need to serialize None values, in order to dump `None` current-snapshot-id as `-1`
#     132     exclude_none = False if Config().get_bool("legacy-current-snapshot-id") else True
#
# File ~/werk/odp_lab/.venv/lib/python3.12/site-packages/pyiceberg/io/pyarrow.py:368, in PyArrowFile.create(self, overwrite)
#     367         raise FileExistsError(f"Cannot create file, already exists: {self.location}")
# --> 368     output_file = self._filesystem.open_output_stream(self._path, buffer_size=self._buffer_size)
#     369 except PermissionError:
#
# File ~/werk/odp_lab/.venv/lib/python3.12/site-packages/pyarrow/_fs.pyx:913, in pyarrow._fs.FileSystem.open_output_stream()
#
# File ~/werk/odp_lab/.venv/lib/python3.12/site-packages/pyarrow/error.pxi:155, in pyarrow.lib.pyarrow_internal_check_status()
#
# File ~/werk/odp_lab/.venv/lib/python3.12/site-packages/pyarrow/error.pxi:92, in pyarrow.lib.check_status()
#
# OSError: When initiating multiple part upload for key 'test_schema.yellow_taxi_2/metadata/00000-ac05c051-2434-4619-84ae-ecba0a3f2998.metadata.json' in bucket 'warehouse': AWS Error NO_SUCH_BUCKET during CreateMultipartUpload operation: The specified bucket does not exist (Request ID: 1890511A79AF8529)
#
# During handling of the above exception, another exception occurred:
#
# NoSuchObjectException                     Traceback (most recent call last)
# ~/werk/odp_lab/.venv/lib/python3.12/site-packages/pyiceberg/catalog/hive.py in ?(self, open_client, database_name, table_name)
#     392             return open_client.get_table(dbname=database_name, tbl_name=table_name)
#     393         except NoSuchObjectException as e:
# --> 394             raise NoSuchTableError(f"Table does not exists: {table_name}") from e
#
# ~/werk/odp_lab/.venv/lib/python3.12/site-packages/hive_metastore/ThriftHiveMetastore.py in ?(self, dbname, tbl_name)
#    4240         """
#    4241         self.send_get_table(dbname, tbl_name)
# -> 4242         return self.recv_get_table()
#
# ~/werk/odp_lab/.venv/lib/python3.12/site-packages/hive_metastore/ThriftHiveMetastore.py in ?(self)
#    4267             raise result.o1
#    4268         if result.o2 is not None:
# -> 4269             raise result.o2
#    4270         raise TApplicationException(TApplicationException.MISSING_RESULT, "get_table failed: unknown result")
#
# NoSuchObjectException: NoSuchObjectException(message='hive.test_schema.yellow_taxi_2 table not found')
#
# The above exception was the direct cause of the following exception:
#
# NoSuchTableError                          Traceback (most recent call last)
# Cell In[11], line 11
#       5     table = catalog.create_table(
#       6         table_id,
#       7         schema=arrow_table.schema,
#       8         location=f"s3a://warehouse/{table_id}"
#       9     )
#      10 except Exception:
# ---> 11     table = catalog.load_table(table_id)
#
# File ~/werk/odp_lab/.venv/lib/python3.12/site-packages/pyiceberg/catalog/hive.py:615, in HiveCatalog.load_table(self, identifier)
#     612 database_name, table_name = self.identifier_to_database_and_table(identifier, NoSuchTableError)
#     614 with self._client as open_client:
# --> 615     hive_table = self._get_hive_table(open_client, database_name, table_name)
#     617 return self._convert_hive_into_iceberg(hive_table)
#
# File ~/werk/odp_lab/.venv/lib/python3.12/site-packages/pyiceberg/catalog/hive.py:394, in HiveCatalog._get_hive_table(self, open_client, database_name, table_name)
#     392     return open_client.get_table(dbname=database_name, tbl_name=table_name)
#     393 except NoSuchObjectException as e:
# --> 394     raise NoSuchTableError(f"Table does not exists: {table_name}") from e
#
# NoSuchTableError: Table does not exists: yellow_taxi_2

# %%
table.append(arrow_table)
print("✅ Data taxi berhasil di-append!")

# %%
# Menghapus tabel tertentu
catalog.drop_table("test_schema.yellow_taxi")

print("Tabel yellow_taxi telah dihapus dari Metastore dan file di MinIO akan dibersihkan.")

# %%
catalog.drop_namespace("test_schema")
print("Namespace test_schema berhasil dihapus.")

# %%
from pyiceberg.catalog import load_catalog

catalog = load_catalog(
    "default",
    **{
        "type": "hive",
        "uri": "thrift://hive-metastore:9083",  # Lebih rapi pakai hostname
        "s3.endpoint": "http://minio:9000",      # Lebih rapi pakai hostname
        "s3.access-key-id": "minioadmin",
        "s3.secret-access-key": "minioadmin",
        "s3.use-ssl": "false",
    }
)

# %%
# Nama schema yang ingin dibuat
schema_name = "bronze"
# Lokasi fizikal di MinIO (pastikan diakhiri dengan /)
schema_location = "s3a://lakehouse/bronze/"


# Cara membuat namespace dengan properties location
try:
    catalog.create_namespace(
        schema_name, 
        properties={"location": schema_location}
    )
    print(f"✅ Schema '{schema_name}' berhasil dibuat di {schema_location}")
except Exception as e:
    print(f"❌ Gagal atau Schema mungkin sudah wujud: {e}")
# Out:
# ❌ Gagal atau Schema mungkin sudah wujud: Database bronze already exists

# %%
import pandas as pd
import pyarrow as pa

df = pd.read_parquet("../data/yellow_tripdata_2023-01.parquet")

arrow_table = pa.Table.from_pandas(df)

table_name = "yellow_taxi_2"
table_id = f"{schema_name}.{table_name}"  # Menjadi 'bronze.yellow_taxi'

# Lokasi fisik di MinIO
table_location = f"s3a://lakehouse/bronze/{table_name}"

# %%
try:
    # 1. Coba buat tabel baru
    table = catalog.create_table(
        identifier=table_id,
        schema=arrow_table.schema,
        location=table_location
    )
    print(f"✅ Tabel {table_id} berhasil dibuat baru.")
except Exception:
    # 2. Jika sudah ada, load tabel yang sudah ada
    table = catalog.load_table(table_id)
    print(f"ℹ️ Tabel {table_id} sudah ada, memuat tabel...")

# 3. Masukkan data (Append)
table.append(arrow_table)
print(f"🚀 Data berhasil dimuat ke {table_id}!")
# Out:
# ✅ Tabel bronze.yellow_taxi_2 berhasil dibuat baru.
# 🚀 Data berhasil dimuat ke bronze.yellow_taxi_2!

# %%
# import s3fs

# # Inisialisasi koneksi ke MinIO
# fs = s3fs.S3FileSystem(
#     key='minioadmin',
#     secret='minioadmin',
#     client_kwargs={'endpoint_url': 'http://minio:9000'}
# )

# # Hapus folder yang tertinggal
# path_lama = "warehouse/test_schema.yellow_taxi"
# if fs.exists(path_lama):
#     fs.rm(path_lama, recursive=True)
#     print(f"✅ Folder {path_lama} berhasil dibersihkan dari MinIO.")
